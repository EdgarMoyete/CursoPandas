# %% [markdown]
# ### Developer: Edgar Moises Hernandez-Gonzalez
# ### Leer Excel

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
pd.read_excel("/content/drive/My Drive/Documentos/Moyete/Canal/CursoPandas/Ejemplo.xlsx")
# Out:
#                Puesto  Salario
# 0   Backend Developer     1100
# 1  Frontend Developer      900
# 2        Data Science     1500
# 3                 DBA     1000
# 4               Movil     1000
