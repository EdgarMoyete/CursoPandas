# %% [markdown]
# ### Developer: Edgar Moises Hernandez-Gonzalez
# ### Graficas con pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame([
                   [0,0],
                   [1,1],
                   [2,4],
                   [3,9],
                   [4,16],
                   [5,25],
                   [6,36],
                   [7,49],
                   [8,64],
                   [9,81]
                   ],
                  columns = ["x", "x^2"])
df
# Out:
#    x  x^2
# 0  0    0
# 1  1    1
# 2  2    4
# 3  3    9
# 4  4   16
# 5  5   25
# 6  6   36
# 7  7   49
# 8  8   64
# 9  9   81

# %%
df.plot()

# %% [markdown]
# ### Histograma

# %%
edades = [12, 15, 13, 12, 18, 20, 19, 20, 13, 12, 13, 17, 15, 16, 13, 14, 13, 17, 19]

# %%
datos = pd.Series(edades)

# %%
print(len(datos))
print(sorted(datos))
# Out:
# 19
# [12, 12, 12, 13, 13, 13, 13, 13, 14, 15, 15, 16, 17, 17, 18, 19, 19, 20, 20]

# %%
datos.hist(bins=8)

# %%
datos.hist(bins=10)
