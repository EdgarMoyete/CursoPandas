# %% [markdown]
# ### Developer: Edgar Moises Hernandez-Gonzalez
# ### Leer y guardar archivos .json

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_json("/content/drive/My Drive/Documentos/Moyete/Canal/CursoPandas/productos.json")

# %%
df
# Out:
#      producto  precio  stock
# 0    Refresco      30    100
# 1    Galletas      12     90
# 2        Jugo      12     80
# 3        Agua       6     70
# 4  Chocolates      20     60
# 5       Leche      18     50

# %%
df_nuevo = df.drop(["stock"], axis=1)

# %%
df_nuevo
# Out:
#      producto  precio
# 0    Refresco      30
# 1    Galletas      12
# 2        Jugo      12
# 3        Agua       6
# 4  Chocolates      20
# 5       Leche      18

# %%
df_nuevo.to_json("/content/drive/My Drive/Documentos/Moyete/Canal/CursoPandas/productosColumns.json", orient="columns")

# %%
df_nuevo.to_json("/content/drive/My Drive/Documentos/Moyete/Canal/CursoPandas/productosRecords.json", orient="records")

# %%
df_columns = pd.read_json("/content/drive/My Drive/Documentos/Moyete/Canal/CursoPandas/productosColumns.json")

# %%
df_columns
# Out:
#      producto  precio
# 0    Refresco      30
# 1    Galletas      12
# 2        Jugo      12
# 3        Agua       6
# 4  Chocolates      20
# 5       Leche      18

# %%
df_records = pd.read_json("/content/drive/My Drive/Documentos/Moyete/Canal/CursoPandas/productosRecords.json")

# %%
df_records
# Out:
#      producto  precio
# 0    Refresco      30
# 1    Galletas      12
# 2        Jugo      12
# 3        Agua       6
# 4  Chocolates      20
# 5       Leche      18
